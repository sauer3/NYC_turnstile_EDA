# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download data from MTA

# %%
url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_190601.txt"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555

# %% [markdown]
# pseudo code
# - calculate the number of people entering each station for every timestamp
#     - the number of entries is cumulative (when does it reset to 0?)
# - calculate the number of people exiting each station for every timestamp

# %%
# get rid of extra strings in columns 
df.columns = df.columns.str.replace(" ", "")

# %%
# Use diff() to derrive the actual number of people from the culmulative value for entries and exits for each SCP
# abs() is used to account for the turnstiles that count backwards
df['people_in'] = df.groupby(['STATION', 'UNIT', 'SCP'])['ENTRIES'].transform(lambda x: x.diff().abs())
df['people_out'] = df.groupby(['STATION', 'UNIT', 'SCP'])['EXITS'].transform(lambda x: x.diff().abs())

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES    EXITS  people_in  people_out
# 0  REGULAR  7071830  2396411        nan         nan
# 1  REGULAR  7071844  2396415     14.000       4.000
# 2  REGULAR  7071864  2396443     20.000      28.000
# 3  REGULAR  7071943  2396500     79.000      57.000
# 4  REGULAR  7072182  2396555    239.000      55.000

# %%
# show which rows are NaN - each nan is at the beginning of a new scp
df[df['people_in'].isna()].head(40)
# Out:
#        C/A  UNIT       SCP     STATION LINENAME DIVISION        DATE  \
# 0     A002  R051  02-00-00       59 ST  NQR456W      BMT  05/25/2019
# 42    A002  R051  02-00-01       59 ST  NQR456W      BMT  05/25/2019
# 84    A002  R051  02-03-00       59 ST  NQR456W      BMT  05/25/2019
# 126   A002  R051  02-03-01       59 ST  NQR456W      BMT  05/25/2019
# 168   A002  R051  02-03-02       59 ST  NQR456W      BMT  05/25/2019
# 210   A002  R051  02-03-03       59 ST  NQR456W      BMT  05/25/2019
# 252   A002  R051  02-03-04       59 ST  NQR456W      BMT  05/25/2019
# 294   A002  R051  02-03-05       59 ST  NQR456W      BMT  05/25/2019
# 336   A002  R051  02-03-06       59 ST  NQR456W      BMT  05/25/2019
# 378   A002  R051  02-05-00       59 ST  NQR456W      BMT  05/25/2019
# 420   A002  R051  02-05-01       59 ST  NQR456W      BMT  05/25/2019
# 462   A002  R051  02-06-00       59 ST  NQR456W      BMT  05/25/2019
# 504   A006  R079  00-00-00  5 AV/59 ST     NQRW      BMT  05/25/2019
# 548   A006  R079  00-00-01  5 AV/59 ST     NQRW      BMT  05/25/2019
# 592   A006  R079  00-00-02  5 AV/59 ST     NQRW      BMT  05/25/2019
# 636   A006  R079  00-00-03  5 AV/59 ST     NQRW      BMT  05/25/2019
# 680   A006  R079  00-00-04  5 AV/59 ST     NQRW      BMT  05/25/2019
# 724   A006  R079  00-03-00  5 AV/59 ST     NQRW      BMT  05/25/2019
# 768   A006  R079  00-03-01  5 AV/59 ST     NQRW      BMT  05/25/2019
# 812   A006  R079  00-03-02  5 AV/59 ST     NQRW      BMT  05/25/2019
# 856   A007  R079  01-05-00  5 AV/59 ST     NQRW      BMT  05/25/2019
# 898   A007  R079  01-05-01  5 AV/59 ST     NQRW      BMT  05/25/2019
# 940   A007  R079  01-06-00  5 AV/59 ST     NQRW      BMT  05/25/2019
# 982   A007  R079  01-06-01  5 AV/59 ST     NQRW      BMT  05/25/2019
# 1024  A007  R079  01-06-02  5 AV/59 ST     NQRW      BMT  05/25/2019
# 1066  A007  R079  01-06-03  5 AV/59 ST     NQRW      BMT  05/25/2019
# 1108  A010  R080  00-00-00  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1150  A010  R080  00-00-01  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1192  A010  R080  00-00-02  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1234  A010  R080  00-00-03  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1276  A010  R080  00-00-04  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1318  A010  R080  00-00-05  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1360  A010  R080  00-00-06  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1402  A010  R080  00-00-07  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1444  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1486  A011  R080  01-00-01  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1528  A011  R080  01-00-02  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1570  A011  R080  01-00-03  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1612  A011  R080  01-00-04  57 ST-7 AV     NQRW      BMT  05/25/2019
# 1654  A013  R081  01-00-00       49 ST     NQRW      BMT  05/25/2019
#
#           TIME     DESC    ENTRIES     EXITS  people_in  people_out
# 0     00:00:00  REGULAR    7071830   2396411        nan         nan
# 42    00:00:00  REGULAR    6298050   1412557        nan         nan
# 84    00:00:00  REGULAR    1236982   4651756        nan         nan
# 126   00:00:00  REGULAR    1115712   1720977        nan         nan
# 168   00:00:00  REGULAR    6200254   8353543        nan         nan
# 210   00:00:00  REGULAR    5754201   6607896        nan         nan
# 252   00:00:00  REGULAR    7133706   3699957        nan         nan
# 294   00:00:00  REGULAR   11441906   1401251        nan         nan
# 336   00:00:00  REGULAR    8980953    499358        nan         nan
# 378   00:00:00  REGULAR        129         0        nan         nan
# 420   00:00:00  REGULAR          0       824        nan         nan
# 462   00:00:00  REGULAR     204355      5989        nan         nan
# 504   02:00:00  REGULAR    3875624   6660863        nan         nan
# 548   02:00:00  REGULAR    5038757   3110650        nan         nan
# 592   02:00:00  REGULAR    6158604  16444823        nan         nan
# 636   02:00:00  REGULAR    2974389   1076872        nan         nan
# 680   02:00:00  REGULAR    7654416   3327341        nan         nan
# 724   02:00:00  REGULAR    9127180   3985786        nan         nan
# 768   02:00:00  REGULAR     188056     98616        nan         nan
# 812   02:00:00  REGULAR     410361    333754        nan         nan
# 856   02:00:00  REGULAR       3417         0        nan         nan
# 898   02:00:00  REGULAR          1      1294        nan         nan
# 940   02:00:00  REGULAR     577793    189836        nan         nan
# 982   02:00:00  REGULAR  119348906   2785441        nan         nan
# 1024  02:00:00  REGULAR    4860187   1975439        nan         nan
# 1066  02:00:00  REGULAR    7399554   2714266        nan         nan
# 1108  00:00:00  REGULAR    4380010   2147262        nan         nan
# 1150  00:00:00  REGULAR   15167351   5793509        nan         nan
# 1192  00:00:00  REGULAR   11056771   4368519        nan         nan
# 1234  00:00:00  REGULAR    3500443   1728387        nan         nan
# 1276  00:00:00  REGULAR    4342879   2163545        nan         nan
# 1318  00:00:00  REGULAR    1563317    461865        nan         nan
# 1360  00:00:00  REGULAR   18818581   5265268        nan         nan
# 1402  00:00:00  REGULAR    1982730    259699        nan         nan
# 1444  00:00:00  REGULAR     187705    741493        nan         nan
# 1486  00:00:00  REGULAR     265423    436419        nan         nan
# 1528  00:00:00  REGULAR     280469    480451        nan         nan
# 1570  00:00:00  REGULAR     420720    361546        nan         nan
# 1612  00:00:00  REGULAR    3109240   2333566        nan         nan
# 1654  00:00:00  REGULAR    6053842  37207946        nan         nan

# %%
# Remove nan data for now
df = df.dropna()

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)
df.describe()
# Out:
#          ENTRIES      EXITS  people_in  people_out
# count      34741      34741      34741       34741
# mean    76680808   68480113        230         187
# std    293850001  276262521       1312         335
# min            0          0          0           0
# 25%       736072     340608         17          14
# 50%      3775860    2263910        107          80
# 75%      9471399    6762773        315         233
# max   2129287095 2062380166     238229       27787

# %% [markdown]
# ### Incorporate Jieun's analysis and select only the top 30 stations

# %%
# list of top 30 stations from Jieun's notebook
stations = ['23 ST', '42 ST-PORT AUTH', 'CANAL ST', '59 ST', '14 ST', '125 ST',
       '104 ST', 'TIMES SQ-42 ST', 'DEKALB AV', '86 ST', 'FRANKLIN AV',
       '145 ST', '167 ST', 'LEXINGTON AV/53', '72 ST', 'GUN HILL RD',
       'BOWLING GREEN', 'FULTON ST', 'GRD CNTRL-42 ST', '66 ST-LINCOLN',
       'KINGS HWY', 'GRAND ST', 'KINGSBRIDGE RD', '34 ST-PENN STA',
       'CHAMBERS ST', 'FORDHAM RD', '116 ST', '96 ST', '50 ST',
       'FT HAMILTON PKY']

# %%
# select only top 30 stations from data frame
df = df[df['STATION'].isin(stations)]

# %% [markdown]
# ### Create a map of the top 30 stations

# %%
# Remove outliers
df = df[(np.abs(stats.zscore(df["people_out"])) < 3)]

# %% [markdown]
# ### Make Graphs showing frequency for time of day and day of week
# - for now it will be a random selection of stations but we will choose the stations we want to select

# %%
# Create a day of week column
df['DATE'] = pd.to_datetime(df['DATE'])
df['weekday'] = df['DATE'].dt.day_name()
df['hour'] = df['TIME'].astype(str).str[:2]

# %%
# create data structure for plotting

data = df[['DATE', 'hour', 'weekday', 'people_out']].groupby(['DATE', 'weekday', 'hour'], as_index=False).sum()
data.sort_values(by=['DATE', 'weekday', 'hour'], inplace=True)
sns.lineplot(x='hour', y='people_out', hue='weekday', data=data)
plt.xticks(rotation='vertical');

# %%
sns.kdeplot(data=data['people_out'], cumulative=True);

# %%
# Remove Saturday and Sunday - we want to target commuters and street teams don't want to work on the weekend
df = df[~df['weekday'].isin(['Saturday', 'Sunday'])]

# %%
heat_df = df.filter(['weekday','STATION','people_out'], axis=1)
heat_df.head()
# Out:
#    weekday STATION  people_out
# 12  Monday   59 ST      18.000
# 13  Monday   59 ST       3.000
# 14  Monday   59 ST      31.000
# 15  Monday   59 ST      51.000
# 16  Monday   59 ST      40.000

# %%
heat_df = heat_df.pivot_table(index='weekday', columns='STATION', values='people_out', aggfunc='sum')
sns.heatmap(heat_df)
